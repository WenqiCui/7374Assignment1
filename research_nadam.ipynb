# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/WenqiCui/7374Assignment1/blob/master/research_nadam.ipynb)

# %%
import keras 
from keras.models import Sequential
from keras.layers import  Conv2D, MaxPooling2D, Dense, Flatten,Dropout,Activation
from keras.layers import BatchNormalization
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt 
import numpy as np
from keras import regularizers
from keras.datasets import cifar10
from keras.optimizers import SGD 

(x_train,y_train),(x_test,y_test) = cifar10.load_data()

print('Shape of training dataset :',x_train.shape)
print('Shape of testing dataste :' ,x_test.shape)

#formatting the dataset 
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train = x_train/255.
x_test = x_test/255.

y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 19s 0us/step
# Shape of training dataset : (50000, 32, 32, 3)
# Shape of testing dataste : (10000, 32, 32, 3)

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),input_shape=[32,32,3],kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(32,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(64,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(128,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(256,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(256,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv2D(512,(3,3),kernel_regularizer=regularizers.l2(0.0003),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(MaxPooling2D(2,2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))

model.summary()

#SGD = SGD(lr=0.01, decay=1e-6, momentum=0.9)
nadam = keras.optimizers.Nadam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004)
model.compile(loss='categorical_crossentropy',optimizer=nadam,metrics=['accuracy'])
datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip = False)

# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(x_train)

# fits the model on batches with real-time data augmentation:
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=32),
                    steps_per_epoch=len(x_train) / 32, epochs=50,
                    validation_data = (x_test,y_test))


plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_11 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_17 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_18 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 2, 2, 512)         1180160
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# activation_20 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 5,774,378
# Trainable params: 5,770,410
# Non-trainable params: 3,968
# _________________________________________________________________
# Epoch 1/50
# 1563/1562 [==============================] - 152s 98ms/step - loss: 3.9990 - acc: 0.1147 - val_loss: 2.6494 - val_acc: 0.1640
# Epoch 2/50
# 1563/1562 [==============================] - 140s 90ms/step - loss: 2.2503 - acc: 0.2443 - val_loss: 2.0833 - val_acc: 0.3140
# Epoch 3/50
# 1563/1562 [==============================] - 144s 92ms/step - loss: 1.9207 - acc: 0.3594 - val_loss: 2.0305 - val_acc: 0.4065
# Epoch 4/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.7641 - acc: 0.4440 - val_loss: 1.6992 - val_acc: 0.4786
# Epoch 5/50
# 1563/1562 [==============================] - 141s 90ms/step - loss: 1.6452 - acc: 0.5132 - val_loss: 1.7291 - val_acc: 0.4730
# Epoch 6/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 1.5436 - acc: 0.5642 - val_loss: 1.4536 - val_acc: 0.5912
# Epoch 7/50
# 1563/1562 [==============================] - 135s 86ms/step - loss: 1.4783 - acc: 0.5938 - val_loss: 1.4315 - val_acc: 0.6157
# Epoch 8/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.4396 - acc: 0.6108 - val_loss: 1.3715 - val_acc: 0.6352
# Epoch 9/50
# 1563/1562 [==============================] - 139s 89ms/step - loss: 1.4045 - acc: 0.6262 - val_loss: 2.0947 - val_acc: 0.4423
# Epoch 10/50
# 1563/1562 [==============================] - 135s 86ms/step - loss: 1.3859 - acc: 0.6347 - val_loss: 1.2645 - val_acc: 0.6602
# Epoch 11/50
# 1563/1562 [==============================] - 137s 88ms/step - loss: 1.3682 - acc: 0.6434 - val_loss: 1.3400 - val_acc: 0.6464
# Epoch 12/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 1.3485 - acc: 0.6496 - val_loss: 1.4006 - val_acc: 0.6373
# Epoch 13/50
# 1563/1562 [==============================] - 137s 87ms/step - loss: 1.3394 - acc: 0.6574 - val_loss: 1.3232 - val_acc: 0.6464
# Epoch 14/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.3269 - acc: 0.6621 - val_loss: 1.2768 - val_acc: 0.6723
# Epoch 15/50
# 1563/1562 [==============================] - 137s 88ms/step - loss: 1.3188 - acc: 0.6667 - val_loss: 1.2666 - val_acc: 0.6786
# Epoch 16/50
# 1563/1562 [==============================] - 133s 85ms/step - loss: 1.3186 - acc: 0.6672 - val_loss: 1.2118 - val_acc: 0.6938
# Epoch 17/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.3066 - acc: 0.6734 - val_loss: 1.3070 - val_acc: 0.6740
# Epoch 18/50
# 1563/1562 [==============================] - 139s 89ms/step - loss: 1.2972 - acc: 0.6744 - val_loss: 1.1371 - val_acc: 0.7264
# Epoch 19/50
# 1563/1562 [==============================] - 141s 90ms/step - loss: 1.2866 - acc: 0.6792 - val_loss: 1.3044 - val_acc: 0.6938
# Epoch 20/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 1.2850 - acc: 0.6819 - val_loss: 1.3406 - val_acc: 0.6742
# Epoch 21/50
# 1563/1562 [==============================] - 139s 89ms/step - loss: 1.2783 - acc: 0.6831 - val_loss: 1.0760 - val_acc: 0.7414
# Epoch 22/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.2806 - acc: 0.6845 - val_loss: 1.1779 - val_acc: 0.7126
# Epoch 23/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.2703 - acc: 0.6882 - val_loss: 1.2436 - val_acc: 0.6944
# Epoch 24/50
# 1563/1562 [==============================] - 141s 90ms/step - loss: 1.2719 - acc: 0.6869 - val_loss: 1.2040 - val_acc: 0.7049
# Epoch 25/50
# 1563/1562 [==============================] - 139s 89ms/step - loss: 1.2633 - acc: 0.6911 - val_loss: 1.2622 - val_acc: 0.6912
# Epoch 26/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.2654 - acc: 0.6905 - val_loss: 1.1251 - val_acc: 0.7306
# Epoch 27/50
# 1563/1562 [==============================] - 137s 88ms/step - loss: 1.2578 - acc: 0.6922 - val_loss: 1.2109 - val_acc: 0.7117
# Epoch 28/50
# 1563/1562 [==============================] - 137s 88ms/step - loss: 1.2556 - acc: 0.6953 - val_loss: 1.2032 - val_acc: 0.7022
# Epoch 29/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 1.2562 - acc: 0.6938 - val_loss: 1.2792 - val_acc: 0.6914
# Epoch 30/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.2534 - acc: 0.6953 - val_loss: 1.1653 - val_acc: 0.7199
# Epoch 31/50
# 1563/1562 [==============================] - 137s 87ms/step - loss: 1.2487 - acc: 0.6946 - val_loss: 1.1376 - val_acc: 0.7302
# Epoch 32/50
# 1563/1562 [==============================] - 137s 87ms/step - loss: 1.2431 - acc: 0.6985 - val_loss: 1.3001 - val_acc: 0.6854
# Epoch 33/50
# 1563/1562 [==============================] - 132s 85ms/step - loss: 1.2432 - acc: 0.6998 - val_loss: 1.1311 - val_acc: 0.7369
# Epoch 34/50
# 1563/1562 [==============================] - 131s 84ms/step - loss: 1.2424 - acc: 0.6976 - val_loss: 1.5473 - val_acc: 0.6041
# Epoch 35/50
# 1563/1562 [==============================] - 137s 87ms/step - loss: 1.2472 - acc: 0.6971 - val_loss: 1.1169 - val_acc: 0.7352
# Epoch 36/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.2417 - acc: 0.6987 - val_loss: 1.2124 - val_acc: 0.7059
# Epoch 37/50
# 1563/1562 [==============================] - 138s 89ms/step - loss: 1.2371 - acc: 0.7001 - val_loss: 1.1151 - val_acc: 0.7297
# Epoch 38/50
# 1563/1562 [==============================] - 137s 87ms/step - loss: 1.2334 - acc: 0.7041 - val_loss: 1.2344 - val_acc: 0.7156
# Epoch 39/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.2401 - acc: 0.7008 - val_loss: 1.0910 - val_acc: 0.7449
# Epoch 40/50
# 1563/1562 [==============================] - 139s 89ms/step - loss: 1.2331 - acc: 0.7022 - val_loss: 1.0629 - val_acc: 0.7536
# Epoch 41/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.2330 - acc: 0.7031 - val_loss: 1.1614 - val_acc: 0.7259
# Epoch 42/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.2357 - acc: 0.7032 - val_loss: 1.3204 - val_acc: 0.6681
# Epoch 43/50
# 1563/1562 [==============================] - 134s 86ms/step - loss: 1.2318 - acc: 0.7060 - val_loss: 1.3253 - val_acc: 0.6751
# Epoch 44/50
# 1563/1562 [==============================] - 139s 89ms/step - loss: 1.2250 - acc: 0.7071 - val_loss: 1.1100 - val_acc: 0.7414
# Epoch 45/50
# 1563/1562 [==============================] - 141s 91ms/step - loss: 1.2280 - acc: 0.7063 - val_loss: 1.2184 - val_acc: 0.7087
# Epoch 46/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 1.2337 - acc: 0.7040 - val_loss: 1.1199 - val_acc: 0.7365
# Epoch 47/50
# 1563/1562 [==============================] - 140s 89ms/step - loss: 1.2287 - acc: 0.7056 - val_loss: 1.1149 - val_acc: 0.7406
# Epoch 48/50
# 1563/1562 [==============================] - 140s 90ms/step - loss: 1.2266 - acc: 0.7053 - val_loss: 1.2506 - val_acc: 0.6837
# Epoch 49/50
# 1563/1562 [==============================] - 136s 87ms/step - loss: 1.2261 - acc: 0.7061 - val_loss: 1.1784 - val_acc: 0.7225
# Epoch 50/50
# 1563/1562 [==============================] - 138s 88ms/step - loss: 1.2248 - acc: 0.7069 - val_loss: 1.4471 - val_acc: 0.6487
